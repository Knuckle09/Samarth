# %% [markdown]
# # <center> **Minor Project - Stock Price Prediction** </center>

# %% [markdown]
# ***
# ## Introduction :
#
# Utilize Machine Learning techniques to estimate the stock value using the Long Short-term Memory(LSTM) Networks.
#
# ![Stock-Market.jpg](attachment:Stock-Market.jpg)

# %% [raw]
# The columns are:
#
# Open - The price the stock opened at
# High - The highest price during the day
# Low - The lowest price during the day
# Close - The closing price on the trading day
# Adj Close - The price of the stock after paying off the dividends.
# Volume - How many shares were traded

# %%
# Importing necessary libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics
from keras.models import Sequential
from keras.layers import Dense,LSTM,Dropout

# %%
# Importing data
df = pd.read_excel('2021-2022_data.xlsx')
df.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2021-01-04  539.000000  540.799988  515.090027  522.859985  522.859985
# 1 2021-01-05  521.549988  526.780029  515.890015  520.799988  520.799988
# 2 2021-01-06  511.970001  513.099976  499.500000  500.489990  500.489990
# 3 2021-01-07  508.279999  516.440002  506.420013  508.890015  508.890015
# 4 2021-01-08  511.309998  513.239990  504.510010  510.399994  510.399994
#
#     Volume
# 0  4444400
# 1  3133900
# 2  5346200
# 3  3686400
# 4  2973900

# %%
# Check shape of the dataset
df.shape
# Out:
# (276, 7)

# %%
# Info of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       276 non-null    datetime64[ns]
#  1   Open       276 non-null    float64
#  2   High       276 non-null    float64
#  3   Low        276 non-null    float64
#  4   Close      276 non-null    float64
#  5   Adj Close  276 non-null    float64
#  6   Volume     276 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 15.2 KB

# %%
# Description of the dataset
df.describe()
# Out:
#                                 Date        Open        High         Low  \
# count                            276  276.000000  276.000000  276.000000
# mean   2021-07-21 00:36:31.304347904  551.819528  558.492933  544.251957
# min              2021-01-04 00:00:00  378.269989  382.660004  351.459991
# 25%              2021-04-13 18:00:00  511.942497  516.237503  504.562493
# 50%              2021-07-21 12:00:00  540.154999  548.200012  531.875000
# 75%              2021-10-27 06:00:00  595.290008  602.424988  585.382507
# max              2022-02-04 00:00:00  692.349976  700.989990  686.090027
# std                              NaN   62.434781   62.687306   62.256404
#
#             Close   Adj Close        Volume
# count  276.000000  276.000000  2.760000e+02
# mean   551.196774  551.196774  4.647431e+06
# min    359.700012  359.700012  1.287200e+06
# 25%    510.374992  510.374992  2.703775e+06
# 50%    539.934998  539.934998  3.357150e+06
# 75%    593.380005  593.380005  4.452075e+06
# max    691.690002  691.690002  5.890430e+07
# std     62.287856   62.287856  5.132586e+06

# %%
# Sum of null values
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# Looking for the unique values
df.nunique()
# Out:
# Date         276
# Open         274
# High         273
# Low          275
# Close        273
# Adj Close    273
# Volume       276
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
plt.figure(figsize=(15,5))
plt.plot(df['Close'], color="blue")
plt.title('Stock Close Price', fontsize=15)
plt.ylabel('Price in dollars')
plt.show()

# %%
# Splitting the data into training and testing sets

df_train = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])             #70% used as a training data
df_test = pd.DataFrame(df['Close'][int(len(df)*0.70):int(len(df))])   #30% used as a testing data

print(df_train.shape)
print(df_test.shape)
# Out:
# (193, 1)
# (83, 1)

# %%
# Checking the output of training & testing sets
df_train.head()
# Out:
#         Close
# 0  522.859985
# 1  520.799988
# 2  500.489990
# 3  508.890015
# 4  510.399994

# %%
df_test.head()
# Out:
#           Close
# 193  632.659973
# 194  627.039978
# 195  624.940002
# 196  629.760010
# 197  633.799988

# %%
# Scaling the data
scaler = MinMaxScaler(feature_range=(0,1))

# %%
df_train_array = scaler.fit_transform(df_train)
df_train_array
# Out:
# array([[0.24578239],
#        [0.2324162 ],
#        [0.10063575],
#        [0.15513891],
#        [0.16493634],
#        [0.09161691],
#        [0.06014788],
#        [0.14800158],
#        [0.10303645],
#        [0.08434988],
#        [0.10894097],
#        [0.6576696 ],
#        [0.61549466],
#        [0.52030879],
#        [0.46587097],
#        [0.49928627],
#        [0.24850783],
#        [0.34791057],
#        [0.30761754],
#        [0.3507655 ],
#        [0.40994015],
#        [0.35342599],
#        [0.43589396],
#        [0.42700481],
#        [0.40838299],
#        [0.48072939],
#        [0.51005732],
#        [0.47112661],
#        [0.46418392],
#        [0.4691152 ],
#        [0.43057378],
#        [0.41032945],
#        [0.35842183],
#        [0.31663658],
#        [0.3968987 ],
#        [0.44400453],
#        [0.40046727],
#        [0.34953268],
#        [0.42603179],
#        [0.4077343 ],
#        [0.23176751],
#        [0.17071116],
#        [0.2038023 ],
#        [0.05417842],
#        [0.13924212],
#        [0.12691411],
#        [0.24708017],
#        [0.21437851],
#        [0.22884763],
#        [0.25337417],
#        [0.25603426],
#        [0.12853622],
#        [0.17648578],
#        [0.24740451],
#        [0.32513644],
#        [0.23248115],
#        [0.11601335],
#        [0.14968844],
#        [0.18797046],
#        [0.18433695],
#        [0.23799617],
#        [0.35323115],
#        [0.36134171],
#        [0.38638744],
#        [0.40234877],
#        [0.4515963 ],
#        [0.45633275],
#        [0.43991716],
#        [0.44608088],
#        [0.35712446],
#        [0.4168179 ],
#        [0.39942889],
#        [0.45068782],
#        [0.41908909],
#        [0.15520366],
#        [0.15442508],
#        [0.13346731],
#        [0.16428746],
#        [0.13346731],
#        [0.13976111],
#        [0.15585255],
#        [0.18485574],
#        [0.15656618],
#        [0.11808971],
#        [0.07202166],
#        [0.0945366 ],
#        [0.12237211],
#        [0.01109519],
#        [0.06553321],
#        [0.        ],
#        [0.01090055],
#        [0.05443801],
#        [0.02569421],
#        [0.00843491],
#        [0.0176486 ],
#        [0.10829228],
#        [0.08376594],
#        [0.11627295],
#        [0.10615098],
#        [0.11276913],
#        [0.12250181],
#        [0.11568902],
#        [0.09148702],
#        [0.09252519],
#        [0.02887349],
#        [0.06332716],
#        [0.06280817],
#        [0.04807946],
#        [0.00538533],
#        [0.01485841],
#        [0.02459109],
#        [0.09674285],
#        [0.04489998],
#        [0.04820915],
#        [0.08668562],
#        [0.10245251],
#        [0.07799112],
#        [0.15468467],
#        [0.18011929],
#        [0.21463791],
#        [0.27309892],
#        [0.31177024],
#        [0.31481962],
#        [0.28049585],
#        [0.31507902],
#        [0.31793395],
#        [0.36763572],
#        [0.33078136],
#        [0.29704133],
#        [0.33091085],
#        [0.33954061],
#        [0.36140666],
#        [0.40857783],
#        [0.37613557],
#        [0.29412145],
#        [0.3069039 ],
#        [0.29892284],
#        [0.18589411],
#        [0.17382549],
#        [0.19744335],
#        [0.20445099],
#        [0.22015293],
#        [0.22268352],
#        [0.18991692],
#        [0.21145863],
#        [0.19575668],
#        [0.16766157],
#        [0.21003097],
#        [0.25895415],
#        [0.23079409],
#        [0.22703068],
#        [0.20023373],
#        [0.17791344],
#        [0.16701269],
#        [0.20075252],
#        [0.21372943],
#        [0.22015293],
#        [0.23935889],
#        [0.38106686],
#        [0.40163514],
#        [0.44348574],
#        [0.44400453],
#        [0.40617714],
#        [0.42265766],
#        [0.47975596],
#        [0.52686219],
#        [0.54639249],
#        [0.62996378],
#        [0.67200883],
#        [0.68485623],
#        [0.78983934],
#        [0.78555674],
#        [0.73033995],
#        [0.73799627],
#        [0.67681022],
#        [0.60199857],
#        [0.63515447],
#        [0.65870758],
#        [0.67719951],
#        [0.58688037],
#        [0.57202196],
#        [0.68563481],
#        [0.70256958],
#        [0.69692466],
#        [0.69854677],
#        [0.64151303],
#        [0.74020252],
#        [0.81339245],
#        [0.83162498],
#        [0.76803784],
#        [0.97216468],
#        [1.        ],
#        [0.95295872]])

# %%
# Chekcking the shape of scaled array
df_train_array.shape
# Out:
# (193, 1)

# %%
# Preparing the training data

X_train = []
y_train = []

for i in range(100,df_train_array.shape[0]):
    X_train.append(df_train_array[i-100:i])
    y_train.append(df_train_array[i,0])

X_train,y_train = np.array(X_train),np.array(y_train)

# %%
# Building model of 4 LSTM network followed by Dropout layout

model = Sequential()

model.add(LSTM(units=50, activation = 'relu', return_sequences = True, input_shape = (X_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units=60, activation = 'relu', return_sequences = True))
model.add(Dropout(0.3))

model.add(LSTM(units=80, activation = 'relu', return_sequences = True))
model.add(Dropout(0.4))

model.add(LSTM(units=120, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(units = 1))

# %%
# Checking the summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  dropout (Dropout)           (None, 100, 50)           0
#
#  lstm_1 (LSTM)               (None, 100, 60)           26640
#
#  dropout_1 (Dropout)         (None, 100, 60)           0
#
#  lstm_2 (LSTM)               (None, 100, 80)           45120
#
#  dropout_2 (Dropout)         (None, 100, 80)           0
#
#  lstm_3 (LSTM)               (None, 120)               96480
#
#  dropout_3 (Dropout)         (None, 120)               0
#
#  dense (Dense)               (None, 1)                 121
#
# =================================================================
# Total params: 178761 (698.29 KB)
# Trainable params: 178761 (698.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compiling & fitting the model

model.compile(optimizer = 'adam', loss = 'mean_squared_error')
hist = model.fit(X_train,y_train, epochs = 50, batch_size = 32, verbose = 2 )
# Out:
# Epoch 1/50
# 3/3 - 7s - loss: 0.1929 - 7s/epoch - 2s/step
# Epoch 2/50
# 3/3 - 1s - loss: 0.1532 - 739ms/epoch - 246ms/step
# Epoch 3/50
# 3/3 - 1s - loss: 0.0880 - 778ms/epoch - 259ms/step
# Epoch 4/50
# 3/3 - 1s - loss: 0.0736 - 757ms/epoch - 252ms/step
# Epoch 5/50
# 3/3 - 1s - loss: 0.0504 - 781ms/epoch - 260ms/step
# Epoch 6/50
# 3/3 - 1s - loss: 0.0559 - 768ms/epoch - 256ms/step
# Epoch 7/50
# 3/3 - 1s - loss: 0.0590 - 773ms/epoch - 258ms/step
# Epoch 8/50
# 3/3 - 1s - loss: 0.0450 - 761ms/epoch - 254ms/step
# Epoch 9/50
# 3/3 - 1s - loss: 0.0384 - 751ms/epoch - 250ms/step
# Epoch 10/50
# 3/3 - 1s - loss: 0.0403 - 1s/epoch - 342ms/step
# Epoch 11/50
# 3/3 - 1s - loss: 0.0379 - 1s/epoch - 466ms/step
# Epoch 12/50
# 3/3 - 1s - loss: 0.0342 - 1s/epoch - 463ms/step
# Epoch 13/50
# 3/3 - 1s - loss: 0.0311 - 1s/epoch - 345ms/step
# Epoch 14/50
# 3/3 - 1s - loss: 0.0265 - 760ms/epoch - 253ms/step
# Epoch 15/50
# 3/3 - 1s - loss: 0.0270 - 786ms/epoch - 262ms/step
# Epoch 16/50
# 3/3 - 1s - loss: 0.0247 - 760ms/epoch - 253ms/step
# Epoch 17/50
# 3/3 - 1s - loss: 0.0288 - 799ms/epoch - 266ms/step
# Epoch 18/50
# 3/3 - 1s - loss: 0.0276 - 756ms/epoch - 252ms/step
# Epoch 19/50
# 3/3 - 1s - loss: 0.0278 - 807ms/epoch - 269ms/step
# Epoch 20/50
# 3/3 - 1s - loss: 0.0258 - 748ms/epoch - 249ms/step
# Epoch 21/50
# 3/3 - 1s - loss: 0.0280 - 765ms/epoch - 255ms/step
# Epoch 22/50
# 3/3 - 1s - loss: 0.0264 - 765ms/epoch - 255ms/step
# Epoch 23/50
# 3/3 - 1s - loss: 0.0233 - 786ms/epoch - 262ms/step
# Epoch 24/50
# 3/3 - 1s - loss: 0.0284 - 754ms/epoch - 251ms/step
# Epoch 25/50
# 3/3 - 1s - loss: 0.0297 - 758ms/epoch - 253ms/step
# Epoch 26/50
# 3/3 - 1s - loss: 0.0260 - 1s/epoch - 386ms/step
# Epoch 27/50
# 3/3 - 1s - loss: 0.0236 - 1s/epoch - 485ms/step
# Epoch 28/50
# 3/3 - 1s - loss: 0.0241 - 1s/epoch - 473ms/step
# Epoch 29/50
# 3/3 - 1s - loss: 0.0268 - 844ms/epoch - 281ms/step
# Epoch 30/50
# 3/3 - 1s - loss: 0.0278 - 765ms/epoch - 255ms/step
# Epoch 31/50
# 3/3 - 1s - loss: 0.0243 - 775ms/epoch - 258ms/step
# Epoch 32/50
# 3/3 - 1s - loss: 0.0269 - 795ms/epoch - 265ms/step
# Epoch 33/50
# 3/3 - 1s - loss: 0.0219 - 776ms/epoch - 259ms/step
# Epoch 34/50
# 3/3 - 1s - loss: 0.0252 - 763ms/epoch - 254ms/step
# Epoch 35/50
# 3/3 - 1s - loss: 0.0225 - 752ms/epoch - 251ms/step
# Epoch 36/50
# 3/3 - 1s - loss: 0.0238 - 764ms/epoch - 255ms/step
# Epoch 37/50
# 3/3 - 1s - loss: 0.0276 - 769ms/epoch - 256ms/step
# Epoch 38/50
# 3/3 - 1s - loss: 0.0222 - 771ms/epoch - 257ms/step
# Epoch 39/50
# 3/3 - 1s - loss: 0.0241 - 741ms/epoch - 247ms/step
# Epoch 40/50
# 3/3 - 1s - loss: 0.0256 - 752ms/epoch - 251ms/step
# Epoch 41/50
# 3/3 - 1s - loss: 0.0267 - 786ms/epoch - 262ms/step
# Epoch 42/50
# 3/3 - 1s - loss: 0.0233 - 1s/epoch - 474ms/step
# Epoch 43/50
# 3/3 - 1s - loss: 0.0315 - 1s/epoch - 465ms/step
# Epoch 44/50
# 3/3 - 1s - loss: 0.0253 - 1s/epoch - 425ms/step
# Epoch 45/50
# 3/3 - 1s - loss: 0.0211 - 777ms/epoch - 259ms/step
# Epoch 46/50
# 3/3 - 1s - loss: 0.0207 - 745ms/epoch - 248ms/step
# Epoch 47/50
# 3/3 - 1s - loss: 0.0235 - 751ms/epoch - 250ms/step
# Epoch 48/50
# 3/3 - 1s - loss: 0.0222 - 764ms/epoch - 255ms/step
# Epoch 49/50
# 3/3 - 1s - loss: 0.0229 - 742ms/epoch - 247ms/step
# Epoch 50/50
# 3/3 - 1s - loss: 0.0241 - 761ms/epoch - 254ms/step

# %%
df_test.head()
# Out:
#           Close
# 193  632.659973
# 194  627.039978
# 195  624.940002
# 196  629.760010
# 197  633.799988

# %% [markdown]
# #### For prediction, we need testing data and if we look the test data from above table. We can say that we need previous days data for  prediction. Hence, for prediction append the 'df_train.tail() to df_test.head()' as mentioned below:

# %%
df_train.tail()
# Out:
#           Close
# 188  613.150024
# 189  603.349976
# 190  634.809998
# 191  639.099976
# 192  631.849976

# %%
# Append testing & training data
past_100_days = df_train.tail(100)

# %%
import pandas as pd

# Assuming past_100_days and df_test are your DataFrames
final_df = pd.concat([past_100_days, df_test], ignore_index=True)

# %%
# Scaling the data

input_data = scaler.fit_transform(final_df)
input_data
# Out:
# array([[0.38127652],
#        [0.38555379],
#        [0.42763338],
#        [0.4162475 ],
#        [0.43133825],
#        [0.42663932],
#        [0.42971167],
#        [0.43422988],
#        [0.43106717],
#        [0.41983186],
#        [0.42031381],
#        [0.39076474],
#        [0.40675919],
#        [0.40651826],
#        [0.39968073],
#        [0.37986081],
#        [0.3842585 ],
#        [0.38877671],
#        [0.42227178],
#        [0.39820472],
#        [0.39974094],
#        [0.4176029 ],
#        [0.42492238],
#        [0.41356665],
#        [0.44917015],
#        [0.46097769],
#        [0.47700229],
#        [0.50414169],
#        [0.52209411],
#        [0.52350972],
#        [0.50757557],
#        [0.52363014],
#        [0.52495549],
#        [0.54802858],
#        [0.53091965],
#        [0.51525649],
#        [0.53097977],
#        [0.53498597],
#        [0.54513686],
#        [0.56703517],
#        [0.55197447],
#        [0.51390099],
#        [0.519835  ],
#        [0.51612995],
#        [0.46365854],
#        [0.45805591],
#        [0.46902005],
#        [0.47227321],
#        [0.47956253],
#        [0.48073731],
#        [0.46552605],
#        [0.47552637],
#        [0.46823705],
#        [0.45519443],
#        [0.47486361],
#        [0.49757525],
#        [0.48450249],
#        [0.4827554 ],
#        [0.47031543],
#        [0.45995366],
#        [0.4548932 ],
#        [0.47055627],
#        [0.47658055],
#        [0.47956253],
#        [0.48847853],
#        [0.55426373],
#        [0.56381216],
#        [0.58324049],
#        [0.58348133],
#        [0.56592069],
#        [0.57357146],
#        [0.60007825],
#        [0.62194641],
#        [0.63101297],
#        [0.66980934],
#        [0.68932794],
#        [0.6952921 ],
#        [0.74402849],
#        [0.74204037],
#        [0.71640704],
#        [0.71996134],
#        [0.69155689],
#        [0.65682703],
#        [0.67221901],
#        [0.68315309],
#        [0.69173762],
#        [0.64980869],
#        [0.64291096],
#        [0.69565354],
#        [0.70351518],
#        [0.70089464],
#        [0.70164767],
#        [0.67517085],
#        [0.72098555],
#        [0.75496257],
#        [0.76342667],
#        [0.73390756],
#        [0.82866952],
#        [0.84159153],
#        [0.81975352],
#        [0.82219335],
#        [0.80526514],
#        [0.79893972],
#        [0.81345826],
#        [0.82562723],
#        [0.80903031],
#        [0.8381878 ],
#        [0.84129039],
#        [0.79954219],
#        [0.8839422 ],
#        [0.91894342],
#        [0.93966677],
#        [0.93020879],
#        [0.9133407 ],
#        [0.94686583],
#        [0.99584324],
#        [0.96831224],
#        [0.95792032],
#        [0.98975866],
#        [0.92984735],
#        [0.86153188],
#        [0.87879156],
#        [0.8924666 ],
#        [0.86511633],
#        [0.89725598],
#        [0.97264973],
#        [0.96277001],
#        [0.98707799],
#        [1.        ],
#        [0.97087267],
#        [0.96117349],
#        [0.90213563],
#        [0.8866532 ],
#        [0.89939448],
#        [0.92153382],
#        [0.916112  ],
#        [0.85002566],
#        [0.77734274],
#        [0.77342681],
#        [0.73023284],
#        [0.76204102],
#        [0.80086754],
#        [0.80839788],
#        [0.7569505 ],
#        [0.75893843],
#        [0.73755232],
#        [0.71776254],
#        [0.73899808],
#        [0.69688844],
#        [0.68384582],
#        [0.70496095],
#        [0.73863664],
#        [0.7667098 ],
#        [0.76625809],
#        [0.76333622],
#        [0.75607704],
#        [0.75556485],
#        [0.76023381],
#        [0.73116659],
#        [0.71589503],
#        [0.69715961],
#        [0.62598275],
#        [0.58311989],
#        [0.54628149],
#        [0.54263673],
#        [0.54561891],
#        [0.53471479],
#        [0.48043617],
#        [0.49998492],
#        [0.45513413],
#        [0.47037555],
#        [0.44745321],
#        [0.11385882],
#        [0.08268316],
#        [0.02024158],
#        [0.        ],
#        [0.08132775],
#        [0.07427927],
#        [0.20313866],
#        [0.29347268],
#        [0.21018706],
#        [0.13825716],
#        [0.15202266]])

# %%
# Checking shape of the input_data
input_data.shape
# Out:
# (183, 1)

# %%
# Preparing the testing data
X_test = []
y_test = []

for i in range(100,input_data.shape[0]):
    X_test.append(input_data[i-100:i])
    y_test.append(input_data[i,0])

X_test,y_test = np.array(X_test), np.array(y_test)
print(X_test.shape)
print(y_test.shape)
# Out:
# (83, 100, 1)
# (83,)

# %%
# Making Predictions

y_pred = model.predict(X_test)
print(y_pred.shape)
# Out:
# 3/3 [==============================] - 1s 78ms/step
# (83, 1)

# %%
# Checking y_test
y_test
# Out:
# array([0.82219335, 0.80526514, 0.79893972, 0.81345826, 0.82562723,
#        0.80903031, 0.8381878 , 0.84129039, 0.79954219, 0.8839422 ,
#        0.91894342, 0.93966677, 0.93020879, 0.9133407 , 0.94686583,
#        0.99584324, 0.96831224, 0.95792032, 0.98975866, 0.92984735,
#        0.86153188, 0.87879156, 0.8924666 , 0.86511633, 0.89725598,
#        0.97264973, 0.96277001, 0.98707799, 1.        , 0.97087267,
#        0.96117349, 0.90213563, 0.8866532 , 0.89939448, 0.92153382,
#        0.916112  , 0.85002566, 0.77734274, 0.77342681, 0.73023284,
#        0.76204102, 0.80086754, 0.80839788, 0.7569505 , 0.75893843,
#        0.73755232, 0.71776254, 0.73899808, 0.69688844, 0.68384582,
#        0.70496095, 0.73863664, 0.7667098 , 0.76625809, 0.76333622,
#        0.75607704, 0.75556485, 0.76023381, 0.73116659, 0.71589503,
#        0.69715961, 0.62598275, 0.58311989, 0.54628149, 0.54263673,
#        0.54561891, 0.53471479, 0.48043617, 0.49998492, 0.45513413,
#        0.47037555, 0.44745321, 0.11385882, 0.08268316, 0.02024158,
#        0.        , 0.08132775, 0.07427927, 0.20313866, 0.29347268,
#        0.21018706, 0.13825716, 0.15202266])

# %%
# Checking y_pred
y_pred
# Out:
# array([[0.809435  ],
#        [0.81973934],
#        [0.83091646],
#        [0.84251225],
#        [0.8542021 ],
#        [0.8658024 ],
#        [0.8770602 ],
#        [0.88796866],
#        [0.8985577 ],
#        [0.90855855],
#        [0.9183092 ],
#        [0.92831266],
#        [0.9390477 ],
#        [0.9507153 ],
#        [0.9632058 ],
#        [0.9765048 ],
#        [0.9908291 ],
#        [1.0060704 ],
#        [1.0219383 ],
#        [1.0383122 ],
#        [1.0546176 ],
#        [1.069845  ],
#        [1.083337  ],
#        [1.094819  ],
#        [1.1040456 ],
#        [1.1112328 ],
#        [1.1172426 ],
#        [1.1227463 ],
#        [1.1283914 ],
#        [1.1346784 ],
#        [1.1416626 ],
#        [1.1491779 ],
#        [1.1565654 ],
#        [1.1631457 ],
#        [1.1685417 ],
#        [1.1727469 ],
#        [1.175837  ],
#        [1.1774656 ],
#        [1.1768909 ],
#        [1.1736813 ],
#        [1.1674387 ],
#        [1.1583531 ],
#        [1.1471236 ],
#        [1.1345589 ],
#        [1.1210432 ],
#        [1.1069262 ],
#        [1.092375  ],
#        [1.077432  ],
#        [1.0623249 ],
#        [1.0470285 ],
#        [1.0314932 ],
#        [1.0158844 ],
#        [1.0006444 ],
#        [0.9863546 ],
#        [0.9734483 ],
#        [0.9621595 ],
#        [0.95250416],
#        [0.9443813 ],
#        [0.93765795],
#        [0.9319794 ],
#        [0.92692333],
#        [0.9220402 ],
#        [0.91656876],
#        [0.90973365],
#        [0.90089107],
#        [0.88973546],
#        [0.8763602 ],
#        [0.86106074],
#        [0.84397984],
#        [0.82550615],
#        [0.8058698 ],
#        [0.7854594 ],
#        [0.76458514],
#        [0.7417629 ],
#        [0.71574306],
#        [0.6857343 ],
#        [0.6517181 ],
#        [0.6145115 ],
#        [0.57519144],
#        [0.5353413 ],
#        [0.4967475 ],
#        [0.46061164],
#        [0.4273773 ]], dtype=float32)

# %% [markdown]
# #### From above y_test & y_pred, we can't recognize how they are matching. hence, for that we need to scale the data.

# %%
# Scaling the data
scaler.scale_
# Out:
# array([0.00301214])

# %%
scale_factor = 1/0.00301214
y_pred = y_pred * scale_factor
y_test = y_test * scale_factor

# %%
# Plotting graph for the result
plt.figure(figsize = (15,5))
plt.plot(y_test,'b',label = 'Original Price')
plt.plot(y_pred,'r',label = 'Predicted Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Conclusion :
# Above graph shows the relation between Actual price(Blue Line) and Predicted price(Red Line) of stock for the mentioned dataset.
